# %%
# Import Dependencies
import pandas as pd
from dbfread import dbf

# %%
# Reference the file where the CSV is located
NYC_df = pd.read_csv("../Resources/NYC_Nhood ACS2008_12.csv")

NYC_safety = pd.read_csv("../Resources/2010_-_2016_School_Safety_Report.csv")
NYC_df.head(20)
# Out:
#     UEMPRATE  cartodb_id  borocode  withssi  withsocial  withpubass  \
# 0   0.095785           1         3      652        5067         277
# 1   0.090011           2         3     2089        7132        1016
# 2   0.130393           3         3     3231        8847        2891
# 3   0.086633           4         3     1103        3508         553
# 4   0.099184           5         4      326        2229         132
# 5   0.056034           6         5      277        2213          58
# 6   0.068092           7         4      267        3324          62
# 7   0.065809           8         5      238        3182         103
# 8   0.068640           9         5      576        5182         172
# 9   0.082542          10         2     2341        5594         886
# 10  0.000000          11         4        0           0           0
# 11  0.073356          12         4     1155        4504         811
# 12  0.077303          13         4      276        1712         356
# 13  0.082949          14         2      582        4015         107
# 14  0.198364          15         2     1590        2074         997
# 15  0.208401          16         3     2654        3412        1207
# 16  0.104419          17         4     1974        4026        1258
# 17  0.080169          18         3       36          47           0
# 18  0.135447          19         2       43          72           7
# 19  0.106788          20         2      842        5119         516
#
#     struggling  profession  popunemplo  poptot    ...     \
# 0         6421         889        2225   48351    ...
# 1        10981        1075        2652   61584    ...
# 2        21235         712        6483  100130    ...
# 3         7188         475        1709   33155    ...
# 4         5307         187        1276   24199    ...
# 5         3183         283         618   24083    ...
# 6         2871        1039         933   25619    ...
# 7         2297         404         941   28727    ...
# 8         3388         357        1461   43427    ...
# 9        11957         219        1894   53800    ...
# 10           0           0           0       0    ...
# 11       12447        1423        2716   60575    ...
# 12        3045         316        1189   28201    ...
# 13        4087         567        1170   26139    ...
# 14        7075          44        2110   27562    ...
# 15        7556         341        2570   30018    ...
# 16        9383         465        2252   50294    ...
# 17          58          28          19     416    ...
# 18         299           0          94    1377    ...
# 19        5918         310        2451   46104    ...
#
#                                             ntaname       boroname  \
# 0    Georgetown-Marine Park-Bergen Beach-Mill Basin       Brooklyn
# 1    Sheepshead Bay-Gerritsen Beach-Manhattan Beach       Brooklyn
# 2                               Crown Heights North       Brooklyn
# 3                                 East Williamsburg       Brooklyn
# 4                                     College Point         Queens
# 5            Charleston-Richmond Valley-Tottenville  Staten Island
# 6              Douglas Manor-Douglaston-Little Neck         Queens
# 7        Annadale-Huguenot-Prince's Bay-Eltingville  Staten Island
# 8                                       Great Kills  Staten Island
# 9   Soundview-Castle Hill-Clason Point-Harding Park          Bronx
# 10                                          Airport         Queens
# 11             Hunters Point-Sunnyside-West Maspeth         Queens
# 12                                         Rosedale         Queens
# 13              Pelham Bay-Country Club-City Island          Bronx
# 14                                      Hunts Point          Bronx
# 15                             Seagate-Coney Island       Brooklyn
# 16                           Far Rockaway-Bayswater         Queens
# 17                       park-cemetery-etc-Brooklyn       Brooklyn
# 18                          park-cemetery-etc-Bronx          Bronx
# 19         Schuylerville-Throgs Neck-Edgewater Park          Bronx
#
#           popdty  ntacode  medianinco  medianagem  medianagef  medianage  \
# 0   4.974987e+05     BK45   1520979.0       663.3       777.1      722.6
# 1   5.892969e+05     BK17   1054259.0       791.4       868.5      827.6
# 2   1.506629e+06     BK61    980637.0       863.1       983.9      923.8
# 3   4.689759e+05     BK90    519058.0       333.6       350.1      341.3
# 4   1.253841e+05     QN23    354073.0       219.0       246.3      232.4
# 5   2.310691e+04     SI11    342708.0       148.3       148.7      148.5
# 6   6.212254e+04     QN45    554014.0       257.5       286.7      273.9
# 7   5.372342e+04     SI01    521048.0       228.8       263.0      248.1
# 8   1.153185e+05     SI54    718593.0       311.1       345.6      330.3
# 9   4.551227e+05     BX09    490852.0       374.9       445.6      413.4
# 10  0.000000e+00     QN98         NaN         NaN         NaN        NaN
# 11  8.781336e+05     QN31         NaN         NaN         NaN        NaN
# 12  9.275115e+04     QN05    506307.0       189.9       220.9      204.3
# 13  1.698278e+05     BX10    340905.0       255.6       280.1      267.5
# 14  3.942480e+05     BX27    149520.0       208.5       246.0      228.5
# 15  2.640941e+05     BK21    236991.0       338.0       385.3      370.6
# 16  2.148538e+05     QN15    354594.0       237.9       275.3      258.0
# 17           NaN     BK99         NaN         NaN         NaN        NaN
# 18  2.062684e+03     BX99         NaN         NaN         NaN        NaN
# 19  2.976638e+05     BX52    958549.0       572.7       627.9      602.0
#
#       HHsize      gini
# 0   2.964211  0.386316
# 1   2.465789  0.448089
# 2   2.429259  0.473667
# 3   2.189000  0.441390
# 4   2.956667  0.413133
# 5   3.002500  0.415000
# 6   2.661667  0.430200
# 7   2.903333  0.404500
# 8   2.837500  0.369787
# 9   3.008333  0.458367
# 10       NaN       NaN
# 11       NaN       NaN
# 12  3.525000  0.341050
# 13  2.353333  0.430983
# 14  2.937500  0.489625
# 15  2.502500  0.433262
# 16  3.088750  0.490038
# 17       NaN       NaN
# 18       NaN       NaN
# 19  2.710667  0.397387
#
# [20 rows x 98 columns]

# %%
NYC_df.rename(columns={"ntaname": "NTA"}, inplace=True)

# %%
NYC_df.head("NTA")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2499f103a563> in <module>()
# ----> 1 NYC_df.head("NTA")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in head(self, n)
#    3970         """
#    3971
# -> 3972         return self.iloc[:n]
#    3973
#    3974     def tail(self, n=5):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2078
#    2079         if isinstance(key, slice):
# -> 2080             return self._get_slice_axis(key, axis=axis)
#    2081
#    2082         if isinstance(key, list):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2046             return obj.copy(deep=False)
#    2047
# -> 2048         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2049         if isinstance(slice_obj, slice):
#    2050             return self._slice(slice_obj, axis=axis, kind='iloc')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _convert_slice_indexer(self, key, axis)
#     264         # if we are accessing via lowered dim, use the last dim
#     265         ax = self.obj._get_axis(min(axis, self.ndim - 1))
# --> 266         return ax._convert_slice_indexer(key, kind=self.name)
#     267
#     268     def _has_valid_setitem_indexer(self, indexer):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    1704         if kind == 'iloc':
#    1705             return slice(self._validate_indexer('slice', key.start, kind),
# -> 1706                          self._validate_indexer('slice', key.stop, kind),
#    1707                          self._validate_indexer('slice', key.step, kind))
#    1708
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    4143             pass
#    4144         elif kind in ['iloc', 'getitem']:
# -> 4145             self._invalid_indexer(form, key)
#    4146         return key
#    4147
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    1861                         "indexers [{key}] of {kind}".format(
#    1862                             form=form, klass=type(self), key=key,
# -> 1863                             kind=type(key)))
#    1864
#    1865     def get_duplicates(self):
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [NTA] of <class 'str'>

# %%
merged_NYC = pd.merge(NYC_df, NYC_safety, on="NTA")

# %%
merged_NYC.head()
# Out:
# Empty DataFrame
# Columns: [UEMPRATE, cartodb_id, borocode, withssi, withsocial, withpubass, struggling, profession, popunemplo, poptot, popover18, popinlabou, poororstru, poor, pacificune, pacificinl, pacific, otherunemp, otherinlab, otherethni, onlyprofes, onlymaster, onlylessth, onlyhighsc, onlydoctor, onlycolleg, onlybachel, okay, mixedunemp, mixedinlab, mixed, master, maleunempl, maleover18, male_pro, male_mastr, male_lesHS, male_HS, male_doctr, male_collg, male_BA, maleinlabo, maledrop, male16to19, male, lessthan10, lessthanhi, households, hispanicun, hispanicin, hispanic, highschool, field_1, femaleunem, femaleover, fem_profes, fem_master, fem_lessHS, fem_HS, fem_doctor, fem_colleg, fem_BA, femaleinla, femaledrop, femal16_19, female, europeanun, europeanin, european, doctorate, comm90plus, comm_less5, comm_60_89, comm_5_14, comm_45_59, comm_30_44, comm_15_29, college, bachelor, asianunemp, asianinlab, asian, americanun, americanin, american, africanune, africaninl, african, NTA, boroname, popdty, ntacode, medianinco, medianagem, medianagef, medianage, HHsize, gini, School Year, Building Code, ...]
# Index: []
#
# [0 rows x 131 columns]
