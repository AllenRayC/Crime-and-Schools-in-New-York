# %%
# Import Dependencies
import pandas as pd
from dbfread import dbf

# %%
# Reference the file where the CSV is located
NYC_df = pd.read_csv("../Resources/NYC_Nhood ACS2008_12.csv")

NYC_safety = pd.read_csv("../Resources/2010_-_2016_School_Safety_Report.csv")
#NYC_df.head(10)

# %%
NYC_df.rename(columns={"ntaname": "NTA"}, inplace=True)

# %%
NYC_df.columns
# Out:
# Index(['UEMPRATE', 'cartodb_id', 'borocode', 'withssi', 'withsocial',
#        'withpubass', 'struggling', 'profession', 'popunemplo', 'poptot',
#        'popover18', 'popinlabou', 'poororstru', 'poor', 'pacificune',
#        'pacificinl', 'pacific', 'otherunemp', 'otherinlab', 'otherethni',
#        'onlyprofes', 'onlymaster', 'onlylessth', 'onlyhighsc', 'onlydoctor',
#        'onlycolleg', 'onlybachel', 'okay', 'mixedunemp', 'mixedinlab', 'mixed',
#        'master', 'maleunempl', 'maleover18', 'male_pro', 'male_mastr',
#        'male_lesHS', 'male_HS', 'male_doctr', 'male_collg', 'male_BA',
#        'maleinlabo', 'maledrop', 'male16to19', 'male', 'lessthan10',
#        'lessthanhi', 'households', 'hispanicun', 'hispanicin', 'hispanic',
#        'highschool', 'field_1', 'femaleunem', 'femaleover', 'fem_profes',
#        'fem_master', 'fem_lessHS', 'fem_HS', 'fem_doctor', 'fem_colleg',
#        'fem_BA', 'femaleinla', 'femaledrop', 'femal16_19', 'female',
# ...

# %%
NYC_safety["NTA"] = NYC_safety["NTA"].str.strip()

# %%
NYC_safety.head()
# Out:
#   School Year Building Code           DBN  \
# 0     2013-14          K001        15K001
# 1     2013-14          K002        17K002
# 2     2013-14          K002        75K141
# 3     2013-14          K002  84K704
# 4     2013-14          K002           NaN
#
#                                Location Name Location Code  \
# 0                        P.S. 001 The Bergen          K001
# 1               Parkside Preparatory Academy          K002
# 2                                  P.S. K141          K141
# 3                     Explore Charter School          K704
# 4  655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
#
#                Address Borough  Geographical District Code Register  \
# 0        309 47 STREET       K                        15.0    1,277
# 1  655 PARKSIDE AVENUE       K                        17.0      479
# 2  655 PARKSIDE AVENUE       K                        17.0      397
# 3  655 PARKSIDE AVENUE       K                        17.0      NaN
# ...

# %%
#NYC_test_NTA = NYC_df.loc[(NYC_df["NTA"] =="College Point")]

# %%
#NYC_test_NTA

# %%
NYC_safety.columns
# Out:
# Index(['School Year', 'Building Code', 'DBN', 'Location Name', 'Location Code',
#        'Address', 'Borough', 'Geographical District Code', 'Register',
#        'Building Name', '# Schools', 'Schools in Building', 'Major N', 'Oth N',
#        'NoCrim N', 'Prop N', 'Vio N', 'ENGroupA', 'RangeA', 'AvgOfMajor N',
#        'AvgOfOth N', 'AvgOfNoCrim N', 'AvgOfProp N', 'AvgOfVio N',
#        'Borough Name', 'Postcode', 'Latitude', 'Longitude', 'Community Board',
#        'Council District ', 'Census Tract', 'BIN', 'BBL', 'NTA'],
#       dtype='object')

# %%
merged_NYC = pd.merge(NYC_df, NYC_safety, on="NTA")

# %%
merged_NYC.head(20)
# Out:
#     UEMPRATE  cartodb_id  borocode  withssi  withsocial  withpubass  \
# 0   0.095785           1         3      652        5067         277
# 1   0.095785           1         3      652        5067         277
# 2   0.095785           1         3      652        5067         277
# 3   0.095785           1         3      652        5067         277
# 4   0.095785           1         3      652        5067         277
# 5   0.095785           1         3      652        5067         277
# 6   0.095785           1         3      652        5067         277
# 7   0.095785           1         3      652        5067         277
# 8   0.095785           1         3      652        5067         277
# 9   0.095785           1         3      652        5067         277
# 10  0.095785           1         3      652        5067         277
# 11  0.095785           1         3      652        5067         277
# 12  0.095785           1         3      652        5067         277
# ...
