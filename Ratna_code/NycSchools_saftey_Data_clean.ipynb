# %% [markdown]
# # NyCity Schools Crimes Versus School Performance Analysis
#
# * As a whole, schools were put under a category of NTA . School safety nos were exracted from NYC Open data for Grad Year 2013-2014
# * School Performance was consiered to a have a direct corelation with school crime . Is there a corelation ?
#
# * The below scripts are for Data Cleanup

# %% [markdown]
# ### Note
# * Author  :  Ratna Kapoor
# This module is to clean the NYC School Safety data , the School Performance and the Census data

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to Load 
ss_data_1416 = "2010-2016_School_Safety_Report.csv"
sp_data_1416 = "Combined_HS_Performance_Data.csv"

# %%
# Read School Safety Data File and store into Pandas Data Frames
ss_data_1416 = pd.read_csv(ss_data_1416)
ss_data_1416.head(5)
# Out:
#   School Year Building Code           DBN  \
# 0     2013-14          K001        15K001
# 1     2013-14          K002        17K002
# 2     2013-14          K002        75K141
# 3     2013-14          K002  84K704
# 4     2013-14          K002           NaN
#
#                                Location Name Location Code  \
# 0                        P.S. 001 The Bergen          K001
# 1               Parkside Preparatory Academy          K002
# 2                                  P.S. K141          K141
# 3                     Explore Charter School          K704
# 4  655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
#
#                Address Borough  Geographical District Code Register  \
# 0        309 47 STREET       K                        15.0    1,277
# 1  655 PARKSIDE AVENUE       K                        17.0      479
# 2  655 PARKSIDE AVENUE       K                        17.0      397
# 3  655 PARKSIDE AVENUE       K                        17.0      NaN
# 4  655 PARKSIDE AVENUE       K                        17.0      876
#
#                                Building Name  \
# 0                                        NaN
# 1  655 PARKSIDE AVENUE CONSOLIDATED LOCATION
# 2  655 PARKSIDE AVENUE CONSOLIDATED LOCATION
# 3  655 PARKSIDE AVENUE CONSOLIDATED LOCATION
# 4  655 PARKSIDE AVENUE CONSOLIDATED LOCATION
#
#                          ...                          Borough Name Postcode  \
# 0                        ...                             BROOKLYN   11220.0
# 1                        ...                             BROOKLYN   11226.0
# 2                        ...                             BROOKLYN   11226.0
# 3                        ...                             BROOKLYN   11226.0
# 4                        ...                             BROOKLYN   11226.0
#
#     Latitude  Longitude  Community Board  Council District   Census Tract  \
# 0  40.649042 -74.012289              7.0               38.0            80
# 1  40.656183 -73.951583              9.0               40.0           802
# 2  40.656183 -73.951583              9.0               40.0           802
# 3  40.656183 -73.951583              9.0               40.0           802
# 4  40.656183 -73.951583              9.0               40.0           802
#
#          BIN            BBL                                                NTA
# 0  3,011,821  3,007,550,022  Sunset Park West                              ...
# 1  3,378,201  3,050,500,051  Prospect Lefferts Gardens-Wingate             ...
# 2  3,378,201  3,050,500,051  Prospect Lefferts Gardens-Wingate             ...
# 3  3,378,201  3,050,500,051  Prospect Lefferts Gardens-Wingate             ...
# 4  3,378,201  3,050,500,051  Prospect Lefferts Gardens-Wingate             ...
#
# [5 rows x 34 columns]

# %%
ss_data_clean_1416 = ss_data_1416.loc[:,["School Year","Building Code","DBN","Location Code","Location Name","Major N","Oth N","NoCrim N","Prop N","Vio N","NTA"]]
ss_data_clean_1416 = ss_data_clean_1416[(ss_data_clean_1416["School Year"] == '2013-14')]
                                        
ss_data_clean_1416.fillna(0, inplace=True)
ss_data_clean_1416.head(5)
# Out:
#   School Year Building Code           DBN Location Code  \
# 0     2013-14          K001        15K001          K001
# 1     2013-14          K002        17K002          K002
# 2     2013-14          K002        75K141          K141
# 3     2013-14          K002  84K704                K704
# 4     2013-14          K002             0             0
#
#                                Location Name  Major N  Oth N  NoCrim N  \
# 0                        P.S. 001 The Bergen      0.0    2.0       1.0
# 1               Parkside Preparatory Academy      0.0    0.0       0.0
# 2                                  P.S. K141      0.0    0.0       0.0
# 3                     Explore Charter School      0.0    0.0       0.0
# 4  655 PARKSIDE AVENUE CONSOLIDATED LOCATION      1.0    5.0       2.0
#
#    Prop N  Vio N                                                NTA
# 0     1.0    0.0  Sunset Park West                              ...
# 1     0.0    0.0  Prospect Lefferts Gardens-Wingate             ...
# 2     0.0    0.0  Prospect Lefferts Gardens-Wingate             ...
# 3     0.0    0.0  Prospect Lefferts Gardens-Wingate             ...
# 4     2.0    4.0  Prospect Lefferts Gardens-Wingate             ...

# %%
#Remove zero crime records
ss_data_clean_1416 = ss_data_clean_1416[(ss_data_clean_1416["Major N"] + ss_data_clean_1416["Oth N"] + ss_data_clean_1416["NoCrim N"] + ss_data_clean_1416["Prop N"] + ss_data_clean_1416["Vio N"]) > 0.0 ]
ss_data_clean_1416.head(5)
# Out:
#   School Year Building Code     DBN Location Code  \
# 0     2013-14          K001  15K001          K001
# 4     2013-14          K002       0             0
# 5     2013-14          K003  13K003          K003
# 6     2013-14          K005  16K005          K005
# 7     2013-14          K006  17K006          K006
#
#                                Location Name  Major N  Oth N  NoCrim N  \
# 0                        P.S. 001 The Bergen      0.0    2.0       1.0
# 4  655 PARKSIDE AVENUE CONSOLIDATED LOCATION      1.0    5.0       2.0
# 5               P.S. 003 The Bedford Village      2.0    0.0       0.0
# 6                 P.S. 005 Dr. Ronald Mcnair      1.0    1.0       0.0
# 7                                   P.S. 006      0.0    1.0       2.0
#
#    Prop N  Vio N                                                NTA
# 0     1.0    0.0  Sunset Park West                              ...
# 4     2.0    4.0  Prospect Lefferts Gardens-Wingate             ...
# 5     2.0    0.0  Clinton Hill                                  ...
# 6     2.0    0.0  Stuyvesant Heights                            ...
# 7     0.0    0.0  Erasmus                                       ...

# %%
ss_renamed_df = ss_data_clean_1416.rename(columns={"Major N": "Major Crime",
                                                       "Oth N": "Other Crime", 
                                                       "NoCrim N": "Non Criminal",
                                                       "Prop N": "Property Crime",
                                                       "Vio N": "Violent Crime"
                                                      })

ss_renamed_df["NTA"] = ss_renamed_df["NTA"].str.strip()

ss_renamed_df.head(5)
# Out:
#   School Year Building Code     DBN Location Code  \
# 0     2013-14          K001  15K001          K001
# 4     2013-14          K002       0             0
# 5     2013-14          K003  13K003          K003
# 6     2013-14          K005  16K005          K005
# 7     2013-14          K006  17K006          K006
#
#                                Location Name  Major Crime  Other Crime  \
# 0                        P.S. 001 The Bergen          0.0          2.0
# 4  655 PARKSIDE AVENUE CONSOLIDATED LOCATION          1.0          5.0
# 5               P.S. 003 The Bedford Village          2.0          0.0
# 6                 P.S. 005 Dr. Ronald Mcnair          1.0          1.0
# 7                                   P.S. 006          0.0          1.0
#
#    Non Criminal  Property Crime  Violent Crime  \
# 0           1.0             1.0            0.0
# 4           2.0             2.0            4.0
# 5           0.0             2.0            0.0
# 6           0.0             2.0            0.0
# 7           2.0             0.0            0.0
#
#                                  NTA
# 0                   Sunset Park West
# 4  Prospect Lefferts Gardens-Wingate
# 5                       Clinton Hill
# 6                 Stuyvesant Heights
# 7                            Erasmus

# %%
#School Safety Data that is clean and sorted by NTA
SS_df = ss_renamed_df.sort_values(["School Year", "NTA", "DBN"], ascending=True)
SS_df.head(5)
# Out:
#      School Year Building Code     DBN Location Code  \
# 1873     2013-14          X144       0             0
# 1741     2013-14          X076  11X076          X076
# 1777     2013-14          X097  11X097          X097
# 1825     2013-14          X121  11X121          X121
# 1613     2013-14          R455       0             0
#
#                                   Location Name  Major Crime  Other Crime  \
# 1873  2545 GUNTHER AVENUE CONSOLIDATED LOCATION          2.0          8.0
# 1741             P.S. 076 The Bennington School          1.0          2.0
# 1777                             P.S. 097 Bronx          0.0          0.0
# 1825                            P.S. 121 Throop          1.0          0.0
# 1613     100 LUTEN AVENUE CONSOLIDATED LOCATION          1.0         12.0
#
#       Non Criminal  Property Crime  Violent Crime  \
# 1873          26.0             3.0            4.0
# 1741           3.0             2.0            1.0
# 1777           1.0             0.0            0.0
# 1825           2.0             1.0            0.0
# 1613          13.0             7.0            6.0
#
#                                              NTA
# 1873                     Allerton-Pelham Gardens
# 1741                     Allerton-Pelham Gardens
# 1777                     Allerton-Pelham Gardens
# 1825                     Allerton-Pelham Gardens
# 1613  Annadale-Huguenot-Prince's Bay-Eltingville

# %%
# Export file as a CSV, without the Pandas index, but with the header
ss_renamed_df.to_csv("SchoolSafety_1314.csv", index=False, header=True)

# %%
### Note
* This module is to clean the School Performance

# %%
# Read School Performance Data File and store into Pandas Data Frames
sp_data_1416 = pd.read_csv(sp_data_1416)
sp_data_1416.head(5)
# Out:
#       DBN graduation_rate_2011 college_career_rate_2011 graduation_rate_2012  \
# 0  01M292               56.30%                   51.90%               50.70%
# 1  01M448               70.70%                   36.30%               74.40%
# 2  01M450               71.60%                   69.20%               72.70%
# 3  01M509               56.40%                   47.70%               59.50%
# 4  01M539               95.30%                   87.00%               97.50%
#
#   college_career_rate_2012 graduation_rate_2013 college_career_rate_2013  \
# 0                   40.00%                  58%                      32%
# 1                   67.30%                  78%                      55%
# 2                   55.70%                  76%                      58%
# 3                   47.90%                  36%                      38%
# 4                   82.80%                  98%                      84%
#
#   graduation_rate_2014 college_career_rate_2014  Community Board  \
# 0                  43%                      41%              3.0
# 1                  80%                      52%              3.0
# 2                  82%                      69%              3.0
# 3                  48%                      26%              3.0
# 4                  95%                      89%              3.0
#
#    Council District  Census Tract              NTA  Precinct
# 0                1.0          201  Lower East Side         7
# 1                1.0          202  Lower East Side         7
# 2                2.0           34     East Village         9
# 3                1.0        3,001        Chinatown         7
# 4                2.0        2,201  Lower East Side         7

# %%
#Remove % from the Grad rate and Coll Rate and convert to float 
for index in range(292):
     sp_data_1416.at[index, "graduation_rate_2014"] = float(sp_data_1416["graduation_rate_2014"][index].replace("%", ""))
     sp_data_1416.at[index, "college_career_rate_2014"] = float(sp_data_1416["college_career_rate_2014"][index].replace("%", ""))

# %%
sp_data_1416
# Out:
#         DBN graduation_rate_2011 college_career_rate_2011  \
# 0    01M292               56.30%                   51.90%
# 1    01M448               70.70%                   36.30%
# 2    01M450               71.60%                   69.20%
# 3    01M509               56.40%                   47.70%
# 4    01M539               95.30%                   87.00%
# 5    01M696               97.60%                   95.70%
# 6    02M047               69.60%                   47.10%
# 7    02M288               82.00%                   62.70%
# 8    02M294               67.50%                   48.30%
# 9    02M296               79.30%                   56.00%
# 10   02M298               91.50%                   79.60%
# 11   02M300               66.30%                   47.50%
# 12   02M303               55.30%                   50.00%
# 13   02M305               67.80%                   54.80%
# 14   02M308               76.20%                   47.80%
# 15   02M316               80.30%                   64.00%
# 16   02M374               77.80%                   40.40%
# 17   02M400               83.20%                   75.60%
# 18   02M407               83.30%                   70.90%
# 19   02M408               93.10%                   60.80%
# 20   02M411              100.00%                   98.10%
# 21   02M412               96.40%                   77.40%
# 22   02M413               84.30%                   65.60%
# 23   02M414               98.00%                   71.70%
# 24   02M416              100.00%                   96.90%
# 25   02M418               97.30%                   88.00%
# 26   02M419               53.10%                   55.90%
# 27   02M420               82.40%                   69.50%
# 28   02M425               79.10%                   38.50%
# 29   02M439               97.80%                   82.00%
# ..      ...                  ...                      ...
# 262  30Q445               56.50%                   43.40%
# 263  30Q450               65.70%                   42.90%
# 264  30Q501               93.40%                   83.60%
# 265  30Q502               72.60%                   48.90%
# 266  30Q555               72.60%                   43.50%
# 267  30Q575               89.00%                   81.30%
# 268  30Q580              100.00%                   90.30%
# 269  31R047               94.10%                   90.10%
# 270  31R080               86.60%                   81.70%
# 271  31R440               75.60%                   47.30%
# 272  31R445               63.90%                   41.40%
# 273  31R450               69.80%                   45.60%
# 274  31R455               83.50%                   63.90%
# 275  31R460               81.20%                   64.70%
# 276  31R600               63.00%                   36.60%
# 277  32K403               72.80%                   38.20%
# 278  32K545               60.10%                   44.80%
# 279  32K549               68.30%                   55.00%
# 280  32K552               63.40%                   25.20%
# 281  32K554              100.00%                   58.10%
# 282  32K556               48.90%                   31.40%
# 283  03M485               98.20%                   86.10%
# 284  31R605              100.00%                   99.00%
# 285  02M475               98.50%                   85.40%
# 286  05M692               98.20%                   93.40%
# 287  10X696              100.00%                   93.60%
# 288  13K430               97.70%                   86.70%
# 289  10X445              100.00%                   99.40%
# 290  14K449               91.40%                   96.10%
# 291  28Q687              100.00%                   97.20%
#
#     graduation_rate_2012 college_career_rate_2012 graduation_rate_2013  \
# 0                 50.70%                   40.00%                  58%
# 1                 74.40%                   67.30%                  78%
# 2                 72.70%                   55.70%                  76%
# 3                 59.50%                   47.90%                  36%
# 4                 97.50%                   82.80%                  98%
# 5                 96.60%                   96.80%                  98%
# 6                 54.80%                   30.40%                  71%
# 7                 77.30%                   59.60%                  84%
# 8                 77.40%                   61.30%                  65%
# 9                 78.40%                   42.70%                  66%
# 10                86.90%                   78.70%                  89%
# 11                61.00%                   46.50%                  55%
# 12                65.20%                   43.40%                  62%
# 13                78.30%                   64.40%                  83%
# 14                68.30%                   58.70%                  75%
# 15                70.50%                   63.90%                  75%
# 16                74.20%                   47.90%                  77%
# 17                82.10%                   81.20%                  83%
# 18                86.40%                   57.40%                  94%
# 19                93.30%                   68.30%                  96%
# 20               100.00%                   90.60%                  99%
# 21                93.10%                   88.30%                  95%
# 22                83.10%                   63.20%                  85%
# 23               100.00%                   85.70%                  98%
# 24                97.80%                   97.40%                 100%
# 25               100.00%                   84.20%                  99%
# 26                50.90%                   43.20%                  50%
# 27                88.20%                   72.00%                  86%
# 28                59.20%                   48.60%                  68%
# 29                98.00%                   76.70%                  97%
# ..                   ...                      ...                  ...
# 262               63.00%                   43.20%                  66%
# 263               56.10%                   42.90%                  59%
# 264               96.60%                   87.60%                  94%
# 265               74.10%                   52.00%                  67%
# 266               66.70%                   44.40%                  70%
# 267               88.10%                   85.20%                  92%
# 268               96.60%                   92.20%                  98%
# 269               96.60%                   82.40%                  97%
# 270               90.00%                   67.70%                  92%
# 271               76.10%                   52.80%                  73%
# 272               62.50%                   47.50%                  61%
# 273               73.80%                   47.70%                  79%
# 274               84.50%                   65.20%                  83%
# 275               78.30%                   74.00%                  81%
# 276               66.80%                   46.10%                  60%
# 277               64.80%                   34.00%                  75%
# 278               66.50%                   47.00%                  70%
# 279               63.50%                   32.70%                  55%
# 280               51.30%                   30.90%                  51%
# 281               97.40%                   77.10%                  97%
# 282               43.20%                   25.20%                  70%
# 283               99.50%                   93.30%                  98%
# 284              100.00%                   90.00%                 100%
# 285               99.40%                   98.70%                  98%
# 286               99.00%                   60.40%                  99%
# 287              100.00%                   98.80%                 100%
# 288               96.00%                   94.80%                  98%
# 289               99.90%                   99.90%                 100%
# 290               98.60%                   85.70%                 100%
# 291               98.30%                  100.00%                  99%
#
#     college_career_rate_2013 graduation_rate_2014 college_career_rate_2014  \
# 0                        32%                   43                       41
# 1                        55%                   80                       52
# 2                        58%                   82                       69
# 3                        38%                   48                       26
# 4                        84%                   95                       89
# 5                        94%                  100                       93
# 6                        42%                   69                       62
# 7                        53%                   77                       49
# 8                        49%                   71                       40
# 9                        52%                   73                       47
# 10                       69%                   94                       68
# 11                       55%                   65                       43
# 12                       52%                   72                       49
# 13                       60%                   87                       69
# 14                       52%                   72                       61
# 15                       48%                   77                       62
# 16                       50%                   74                       54
# 17                       64%                   84                       70
# 18                       58%                   90                       84
# 19                       66%                   94                       66
# 20                       96%                  100                       97
# 21                       73%                   96                       79
# 22                       77%                   91                       78
# 23                       91%                   97                       81
# 24                       97%                  100                       89
# 25                       86%                   99                       88
# 26                       41%                   66                       35
# 27                       77%                   90                       76
# 28                       43%                   64                       41
# 29                       83%                   99                       85
# ..                       ...                  ...                      ...
# 262                      44%                   69                       46
# 263                      40%                   63                       43
# 264                      85%                   98                       80
# 265                      57%                   68                       49
# 266                      45%                   62                       51
# 267                      87%                   89                       91
# 268                      92%                   98                       98
# 269                      95%                   90                       88
# 270                      79%                   91                       79
# 271                      51%                   78                       54
# 272                      42%                   67                       43
# 273                      51%                   80                       56
# 274                      66%                   85                       66
# 275                      69%                   84                       70
# 276                      44%                   75                       42
# 277                      37%                   62                       36
# 278                      42%                   59                       53
# 279                      34%                   69                       31
# 280                      28%                   48                       31
# 281                      84%                   94                       74
# 282                      23%                   68                       38
# 283                      86%                   99                       80
# 284                     100%                  100                       99
# 285                      99%                   99                       97
# 286                      98%                   99                       95
# 287                      99%                  100                       99
# 288                      83%                   98                       91
# 289                     100%                  100                       96
# 290                      87%                   99                       97
# 291                      84%                  100                       89
#
#      Community Board  Council District  Census Tract  \
# 0                3.0                1.0          201
# 1                3.0                1.0          202
# 2                3.0                2.0           34
# 3                3.0                1.0        3,001
# 4                3.0                2.0        2,201
# 5                3.0                2.0        1,002
# 6                6.0                2.0           64
# 7                4.0                3.0          135
# 8                3.0                1.0           18
# 9                4.0                3.0          135
# 10               3.0                1.0           16
# 11               4.0                3.0          135
# 12               4.0                3.0          135
# 13               3.0                1.0           18
# 14               3.0                1.0           18
# 15               1.0                1.0            9
# 16               6.0                2.0           50
# 17               4.0                3.0          139
# 18               6.0                2.0           48
# 19               4.0                3.0          127
# 20               5.0                2.0           56
# 21               4.0                3.0           83
# 22               5.0                2.0           68
# 23               4.0                3.0           83
# 24               8.0                5.0          132
# 25               1.0                1.0            9
# 26               4.0                3.0           89
# 27               6.0                2.0           48
# 28               1.0                1.0           13
# 29               5.0                3.0           58
# ..               ...                ...          ...
# 262              1.0               26.0          163
# 263              1.0               22.0           45
# 264              1.0               26.0           57
# 265              2.0               26.0           19
# 266              1.0               26.0           33
# 267              1.0               26.0           33
# 268              1.0               26.0           55
# 269              2.0               51.0       27,702
# 270              2.0               50.0          177
# 271              2.0               50.0       11,202
# 272              1.0               49.0          213
# 273              1.0               49.0            7
# 274              3.0               51.0          198
# 275              2.0               50.0          181
# 276              1.0               49.0            9
# 277              4.0               37.0          435
# 278              4.0               34.0          393
# 279              4.0               37.0          435
# 280              4.0               37.0          435
# 281              4.0               37.0          433
# 282              4.0               34.0          393
# 283              7.0                6.0          151
# 284              2.0               50.0          134
# 285              1.0                1.0       31,703
# 286              9.0                9.0       21,703
# 287              8.0               11.0          409
# 288              2.0               35.0           33
# 289              7.0               11.0          409
# 290              1.0               34.0          505
# 291             12.0               27.0          246
#
#                                                    NTA  Precinct
# 0                                      Lower East Side         7
# 1                                      Lower East Side         7
# 2                                         East Village         9
# 3                                            Chinatown         7
# 4                                      Lower East Side         7
# 5                                      Lower East Side         7
# 6                                             Gramercy        13
# 7                                              Clinton        18
# 8                                            Chinatown         7
# 9                                              Clinton        18
# 10                                           Chinatown         5
# 11                                             Clinton        18
# 12                                             Clinton        18
# 13                                           Chinatown         7
# 14                                           Chinatown         7
# 15                   Battery Park City-Lower Manhattan         1
# 16                                            Gramercy        13
# 17                                             Clinton        18
# 18                                            Gramercy        13
# 19                                             Clinton        18
# 20          Hudson Yards-Chelsea-Flatiron-Union Square        13
# 21          Hudson Yards-Chelsea-Flatiron-Union Square        10
# 22                                            Gramercy        13
# 23          Hudson Yards-Chelsea-Flatiron-Union Square        10
# 24                         Lenox Hill-Roosevelt Island        19
# 25                   Battery Park City-Lower Manhattan         1
# 26          Hudson Yards-Chelsea-Flatiron-Union Square        10
# 27                                            Gramercy        13
# 28                   Battery Park City-Lower Manhattan         1
# 29          Hudson Yards-Chelsea-Flatiron-Union Square        13
# ..                                                 ...       ...
# 262                                            Astoria       114
# 263                                            Astoria       114
# 264                                            Astoria       114
# 265               Hunters Point-Sunnyside-West Maspeth       108
# 266           Queensbridge-Ravenswood-Long Island City       114
# 267           Queensbridge-Ravenswood-Long Island City       113
# 268           Queensbridge-Ravenswood-Long Island City       114
# 269  Todt Hill-Emerson Hill-Heartland Village-Light...       121
# 270  Todt Hill-Emerson Hill-Heartland Village-Light...       122
# 271                             New Dorp-Midland Beach       122
# 272                                      Port Richmond       121
# 273          West New Brighton-New Brighton-St. George       120
# 274         Annadale-Huguenot-Prince's Bay-Eltingville       123
# 275  Todt Hill-Emerson Hill-Heartland Village-Light...       122
# 276          West New Brighton-New Brighton-St. George       120
# 277                                     Bushwick North        83
# 278                                     Bushwick South        83
# 279                                     Bushwick North        83
# 280                                     Bushwick North        83
# 281                                     Bushwick North        83
# 282                                     Bushwick South        83
# 283                                     Lincoln Square        20
# 284                             New Dorp-Midland Beach       122
# 285                  Battery Park City-Lower Manhattan         1
# 286                                     Manhattanville        26
# 287                              Van Cortlandt Village        50
# 288                                        Fort Greene        88
# 289                              Van Cortlandt Village        52
# 290                                  East Williamsburg        90
# 291                                            Jamaica       103
#
# [292 rows x 14 columns]

# %%
sp_data_1416["graduation_rate_2014"] = pd.to_numeric(sp_data_1416["graduation_rate_2014"])
sp_data_1416["college_career_rate_2014"] = pd.to_numeric(sp_data_1416["college_career_rate_2014"])

# %%
type(sp_data_1416["graduation_rate_2014"][1])
# Out:
# float

# %%
sp_data_clean_14 = sp_data_1416.loc[:,["DBN","graduation_rate_2014","college_career_rate_2014","NTA"]]
sp_data_clean_14['School Year'] = '2013-14'
sp_data_clean_14_df = sp_data_clean_14.rename(columns={"graduation_rate_2014": "Grad_rate",
                                                         "college_career_rate_2014": "Coll_rate"                                                       
                                                      })
# Out:
# DBN             object
# Grad_rate      float64
# Coll_rate      float64
# NTA             object
# School Year     object
# dtype: object

# %%
#Sort teh data and save output
SP_df = sp_data_clean_14_df.sort_values(["School Year", "NTA", "DBN"], ascending=True)

SP_df.head()
# Out:
#         DBN  Grad_rate  Coll_rate                                         NTA  \
# 274  31R455       85.0       66.0  Annadale-Huguenot-Prince's Bay-Eltingville
# 262  30Q445       69.0       46.0                                     Astoria
# 263  30Q450       63.0       43.0                                     Astoria
# 264  30Q501       98.0       80.0                                     Astoria
# 231  25Q285       95.0       80.0                                  Auburndale
#
#     School Year
# 274     2013-14
# 262     2013-14
# 263     2013-14
# 264     2013-14
# 231     2013-14

# %%
# Export file as a CSV, without the Pandas index, but with the header

SP_df.to_csv("SchoolPerfomance_1314.csv", index=False, header=True)
